# %% [markdown]
# # Reflection - Research Agent
#
# A simple agentic workflow designed to simulate reflective thinking in a writing task.

# %%
# import libraries
from dotenv import load_dotenv
import aisuite as ai

# load environment variables
load_dotenv()

# initialize the AI client
client = ai.Client()

# %%
# generate draft function
def generate(prompt: str, model: str = "openai:gpt-4o") -> str:
  instruction = f"""
  Write a well structured draft essay in response to the following prompt.
  The draft should include an introduction, body, and a conclusion.
  prompt: 
  {prompt}
  """

  response = client.chat.completions.create(
      model=model,
      messages=[
          {"role": "user", "content": instruction}
      ],
      temperature=1.0,
  )
  return response.choices[0].message.content

# %%
# generate reflect on draft function
def reflect(draft: str, model: str = "openai:o4-mini") -> str:
    instruction = f"""
    Reflect critically on the following draft essay.
    Identify areas for improvement in structure, clarity, style, or style.
    Provide constructive feedback in paragraph form.

    Draft:
    {draft}
    """
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": instruction}
        ],
        temperature=1.0,
    )
    return response.choices[0].message.content

# %%
# generate revise draft function
def revise(draft: str, feedback: str, model: str = "openai:gpt-4o") -> str:
    instruction = f"""
    Revise the following draft essay using the provided feedback.
    Make improvements in clarity, coherence, argumentation, and flow.
    Return only the improved essay.

    Original Draft:
    {draft}

    Feedback:
    {feedback}
    """
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": instruction}
        ],
        temperature=1.0,
    )
    return response.choices[0].message.content

# %%
from IPython.display import display, HTML

def show_output(title, content, background="#f0f0f0", text_color="#000000"):
    html = f"""
    <div style="
        border: 1px solid #ccc;
        border-radius: 10px;
        padding: 15px;
        margin-bottom: 15px;
        background-color: {background};
        color: {text_color};
    ">
        <h3 style="margin-top: 0;">{title}</h3>
        <pre style="
            white-space: pre-wrap;
            font-family: monospace;
            font-size: 14px;
        ">{content}</pre>
    </div>
    """
    display(HTML(html))

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

#  Draft
draft = generate(essay_prompt)
# Reflection
feedback = reflect(draft)
# Revision
revised = revise(draft, feedback)

# %%
show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Complexities of Government Regulation on Social Media Platforms
#
# Introduction:
#
# In the digital age, social media platforms have become pivotal in shaping societal narratives, influencing political discourse, and fostering global connections. Facebook, Twitter, Instagram, and newer platforms like TikTok are not only arenas for personal expression and communication but also potent tools that can amplify voices, spread information, and sometimes, misinformation. Given their significant impact, a pressing question arises: should governments regulate social media platforms? On one hand, regulation could uphold ethical standards, protect user rights, and mitigate harmful content. On the other, it could risk stifling innovation, infringing on freedom of speech, and establishing precedents for governmental overreach. This essay explores both sides of this contentious issue and seeks to provide a nuanced perspective on the role of government regulation in social media.
#
# Body:
#
# Proponents of governmental regulation argue primarily from the standpoint of safety, accountability, and ethical responsibility. Social media platforms have often been criticized for their role in spreading fake news, hate speech, and harmful content. Without proper oversight, these platforms can unwittingly become breeding grounds for cyberbullying, misinformation, and extremist propaganda. For instance, the propagation of fake news during election cycles has had tangible impacts on democratic processes worldwide, challenging the integrity of free and fair elections. Government regulation could enforce stricter content moderation policies and demand transparency in algorithms that decide what content users see, thereby safeguarding the public sphere against misinformation and harmful content. Furthermore, regulations could mandate privacy standards to protect user data from misuse by corporations or malicious entities, a concern that has grown with controversies like the Cambridge Analytica scandal.
#
# Yet, while the case for regulation might seem compelling, opponents caution against the potential downsides. Chief among these is the threat to freedom of expression—a cornerstone of democracy. Social media often thrives as a space for open discourse, and governmental intervention may lead to censorship or suppression of dissenting voices, especially in autocratic regimes. Any regulation must tread carefully to avoid crossing into authoritarian control of information. Additionally, imposing stringent regulations could stifle innovation. Social media companies, driven by rapid technological advancements, might find themselves hindered by bureaucratic red tape, slowing progress and restricting their ability to adapt to user needs swiftly. The dynamic nature of technology, where changes occur at breakneck speeds, demands a regulatory response that is agile and informed, yet not inhibitive.
#
# Conclusively, the issue of regulating social media platforms presents a complex challenge that requires a balanced approach. The potential harms of leaving these platforms unregulated—ranging from the spread of misinformation to breaches of privacy—are too significant to ignore. Positive regulation could lead to a safer, more transparent online environment. However, any regulatory framework must safeguard against censorship and encourage continuous innovation. It necessitates a collaborative effort, bringing together governments, tech companies, and civil society to create guidelines that are not only enforceable but also adaptable to the fast-evolving digital landscape. Ultimately, the goal should be to ensure that social media serves the public good, amplifying the benefits while minimizing the risks.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The draft offers a solid overview of the debate around social media regulation, but it could be tightened to sharpen its impact. First, the introduction would benefit from a more concise, assertive thesis statement that not only poses the question of regulation but also signals the essay’s unique perspective or roadmap—this will help readers know exactly what to expect. In the body, the two-sided presentation is logical, yet the transitions between “pro” and “con” sections feel abrupt; weaving in brief signposts (for example, “While these benefits are significant, it is equally important to consider…”) would improve the flow. Some passages lean on generalizations or familiar phrases (“cornerstone of democracy,” “red tape”), so substituting precise examples or more vivid language can elevate the argument—perhaps by citing a recent policy proposal or concrete data on content moderation outcomes. Additionally, several sentences run long and pack in multiple ideas; breaking these into shorter, punchier statements will enhance clarity. Finally, the conclusion restates earlier points but stops short of offering a memorable takeaway: consider ending with either a specific policy recommendation or an invitation to further research, ensuring the essay not only surveys the issue but also leaves the reader with a clear sense of direction.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Complexities of Government Regulation on Social Media Platforms
#
# Introduction:
#
# In our interconnected digital world, social media platforms like Facebook, Twitter, Instagram, and TikTok have become integral to shaping public discourse, influencing political processes, and forging global connections. However, their power to amplify both information and misinformation has prompted an urgent debate: should governments regulate these platforms? This essay argues that while regulation is necessary to ensure safety and accountability, it must be carefully balanced to protect freedom of expression and promote innovation.
#
# Body:
#
# On one side of the debate, advocates for regulation emphasize the need for safety and responsibility. Social media platforms, left unchecked, often contribute to the spread of fake news, hate speech, and harmful content, which can have dire consequences, such as undermining democratic elections with misinformation. Government intervention could enforce stricter content moderation and enhance transparency in how content is prioritized, providing a robust defense against misuse. Additionally, regulation could establish stringent privacy safeguards, protecting personal data against exploitation, as seen in incidents like the Cambridge Analytica scandal.
#
# While these benefits are significant, it is equally important to consider the opposing perspective. Critics of regulation argue that it poses a threat to freedom of expression—a fundamental democratic value. Social media has thrived as a haven for open discourse, and excessive regulation could lead to censorship or suppression of dissent, especially in authoritarian settings. Moreover, overly cumbersome regulations may impede technological innovation. The rapid evolution of technology requires a flexible regulatory approach that fosters progress and addresses user needs without stifling social media companies under bureaucratic constraints.
#
# Conclusively, the regulation of social media platforms presents a multifaceted challenge that demands a careful balancing act. Unregulated platforms pose a risk of spreading misinformation and compromising privacy, issues that cannot be neglected. Positive regulation could enhance safety and transparency online, but it must also safeguard free expression and support ongoing innovation. Crafting effective regulation requires collaboration between governments, tech companies, and civil society to formulate adaptable guidelines responding to the digital landscape's swift changes. As a potential path forward, policymakers could consider developing a flexible regulatory framework that evolves with technological advancements, ensuring that social media delivers societal benefits while minimizing its risks.</pre>
#     </div>
