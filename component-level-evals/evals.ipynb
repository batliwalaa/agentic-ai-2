# %% [markdown]
# # Agentic AI - component level evals

# %% [markdown]
# ### import libraries and load environments

# %%
from datetime import datetime
from aisuite import Client
import json
import re

import sys 
from pathlib import Path

parent_dir = Path().resolve().parent
sys.path.append(str(parent_dir))

from research import research_tools as rtools
import utils

client = Client()

# %% [markdown]
# ### Research Step - find references

# %%
def find_references(task: str, model: str = "openai:gpt-4o", return_messages: bool = False):
  """
    Perform a research task using external tools (arXiv, Tavilly, Wikipedia).
  """

  prompt = f"""
  You are a research function with access to
  - arxiv_tool: academic papers
  - tavily_tool: general web search (return json when asked)
  - wikipedai_tool: encyclopedic summaries

  Task:
  {task}

  Today is {datetime.now().strftime('%Y-%m-%d')}.
  """.strip()

  messages = [{ "role": "user", "content": prompt}]

  tools = [
    rtools.arxiv_search,
    rtools.tavily_search,
    rtools.wikipedia_search
  ]

  try:
    response = client.chat.completions.create(
      model=model,
      messages=messages,
      tools=tools,
      tool_choice="auto",
      max_turns=5
    )

    content = response.choices[0].message.content
    return (content, messages) if return_messages else content
  
  except Exception as e:
    return f"[Model error: {e}]"

# %%
research_task = "Find 2 recent papers about recent developments in black hole science"
research_result = find_references(research_task)

utils.print_html(
    research_result,
    title="Research Function Output"
)
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Research Function Output</div><pre><code>I found two academic papers related to recent developments in black hole science:
#
# 1. **Title**: Accretion onto Supermassive Black Holes in Quasars: Learning from Optical/UV Observations
#    - **Authors**: Paola Marziani, Deborah Dultzin-Hacyan, Jack W. Sulentic
#    - **Published**: June 28, 2006
#    - **Abstract URL**: [Read Abstract](http://arxiv.org/abs/astro-ph/0606678v1)
#    - **PDF URL**: [Read PDF](https://arxiv.org/pdf/astro-ph/0606678v1)
#    - **Summary**: This paper discusses the accretion processes in quasars and active galactic nuclei, emphasizing the challenges in understanding the connection between observed spectral properties and physical parameters. It explores the correlations and trends emerging from multivariate analysis, provides a critique on recent estimates of black hole mass and other related parameters, and suggests implications for quasar evolution and broader cosmological questions.
#
# 2. **Title**: Disturbing the Black Hole
#    - **Authors**: Jacob D. Bekenstein
#    - **Published**: May 13, 1998
#    - **Abstract URL**: [Read Abstract](http://arxiv.org/abs/gr-qc/9805045v1)
#    - **PDF URL**: [Read PDF](https://arxiv.org/pdf/gr-qc/9805045v1)
#    - **Summary**: The paper supports the conjecture that the horizon area of a near-equilibrium black hole is an adiabatic invariant. It reviews examples like a Schwarzschild black hole perturbed by quasistatic scalar fields, and explores the implications for black hole quantization.
#
# Both papers provide insights into black hole science, though they may not be from the very latest years due to the limitations of the search.</code></pre></div>

# %% [markdown]
# ### Evaluation Step
# Design a component level evaluation that checks whether the returned domains belong to predefined list of preferred domains.
#
# The evaluation here is objective, so can be evaluated using code.
# - The preferred list of sources for black hole query
# - Extract urls returned in response
# - compare against the preferred list of domains
# - compute ratio of preferred/total_results
# - evaluate PASS/FAIL

# %%
TOP_DOMAINS = [
  # General reference / institutions / publishers
    "wikipedia.org", "nature.com", "science.org", "sciencemag.org", "cell.com",
    "mit.edu", "stanford.edu", "harvard.edu", "nasa.gov", "noaa.gov", "europa.eu",

    # CS/AI venues & indexes
    "arxiv.org", "acm.org", "ieee.org", "neurips.cc", "icml.cc", "openreview.net",

    # Other reputable outlets
    "elifesciences.org", "pnas.org", "jmlr.org", "springer.com", "sciencedirect.com",

    # Extra domains (case-specific additions)
    "pbs.org", "nova.edu", "nvcc.edu", "cccco.edu",

    # Well known programming sites
    "codecademy.com", "datacamp.com"
]

# %%
def evaluate_results(TOP_DOMAINS, raw: str, min_ratio=0.4):
    """
    Evaluate whether plain-text research results mostly come from preferred domains.

    Args:
        TOP_DOMAINS (set[str]): Set of preferred domains (e.g., 'arxiv.org', 'nature.com').
        raw (str): Plain text or Markdown containing URLs.
        min_ratio (float): Minimum preferred ratio required to pass (e.g., 0.4 = 40%).

    Returns:
        tuple[bool, str]: (flag, markdown_report)
            flag -> True if PASS, False if FAIL
            markdown_report -> Markdown-formatted summary of the evaluation
    """

    # Extract URLs from the text
    url_pattern = re.compile(r'https?://[^\s\]\)>\}]+', flags=re.IGNORECASE)
    urls = url_pattern.findall(raw)

    if not urls:
        return False, """### Evaluation — Preferred Domains
          No URLs detected in the provided text. 
          Please include links in your research results.
        """

    # Count preferred vs total
    total = len(urls)
    preferred_count = 0
    details = []

    for url in urls:
        domain = url.split("/")[2]
        preferred = any(td in domain for td in TOP_DOMAINS)
        if preferred:
            preferred_count += 1
        details.append(f"- {url} → {'✅ PREFERRED' if preferred else '❌ NOT PREFERRED'}")

    ratio = preferred_count / total if total > 0 else 0.0
    flag = ratio >= min_ratio

    # Markdown report
    report = f"""
      ### Evaluation — Preferred Domains
      - Total results: {total}
      - Preferred results: {preferred_count}
      - Ratio: {ratio:.2%}
      - Threshold: {min_ratio:.0%}
      - Status: {"✅ PASS" if flag else "❌ FAIL"}

      **Details:**
      {chr(10).join(details)}
    """
    return flag, report

# %%
utils.print_html(json.dumps(list(TOP_DOMAINS)[:4], indent=2), title="Sample Trusted Domains")

utils.print_html("<h3>Research Results</h3>" + research_result, title="Research Results")

flag, report = evaluate_results(TOP_DOMAINS, research_result)
utils.print_html("<pre>" + report + "</pre>", title="<h3>Evaluation Summary</h3>")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Sample Trusted Domains</div><pre><code>[
#   &quot;wikipedia.org&quot;,
#   &quot;nature.com&quot;,
#   &quot;science.org&quot;,
#   &quot;sciencemag.org&quot;
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Research Results</div><pre><code>&lt;h3&gt;Research Results&lt;/h3&gt;I found two academic papers related to recent developments in black hole science:
#
# 1. **Title**: Accretion onto Supermassive Black Holes in Quasars: Learning from Optical/UV Observations
#    - **Authors**: Paola Marziani, Deborah Dultzin-Hacyan, Jack W. Sulentic
#    - **Published**: June 28, 2006
#    - **Abstract URL**: [Read Abstract](http://arxiv.org/abs/astro-ph/0606678v1)
#    - **PDF URL**: [Read PDF](https://arxiv.org/pdf/astro-ph/0606678v1)
#    - **Summary**: This paper discusses the accretion processes in quasars and active galactic nuclei, emphasizing the challenges in understanding the connection between observed spectral properties and physical parameters. It explores the correlations and trends emerging from multivariate analysis, provides a critique on recent estimates of black hole mass and other related parameters, and suggests implications for quasar evolution and broader cosmological questions.
#
# 2. **Title**: Disturbing the Black Hole
#    - **Authors**: Jacob D. Bekenstein
#    - **Published**: May 13, 1998
#    - **Abstract URL**: [Read Abstract](http://arxiv.org/abs/gr-qc/9805045v1)
#    - **PDF URL**: [Read PDF](https://arxiv.org/pdf/gr-qc/9805045v1)
#    - **Summary**: The paper supports the conjecture that the horizon area of a near-equilibrium black hole is an adiabatic invariant. It reviews examples like a Schwarzschild black hole perturbed by quasistatic scalar fields, and explores the implications for black hole quantization.
#
# Both papers provide insights into black hole science, though they may not be from the very latest years due to the limitations of the search.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title"><h3>Evaluation Summary</h3></div><pre><code>&lt;pre&gt;
#       ### Evaluation — Preferred Domains
#       - Total results: 4
#       - Preferred results: 4
#       - Ratio: 100.00%
#       - Threshold: 40%
#       - Status: ✅ PASS
#
#       **Details:**
#       - http://arxiv.org/abs/astro-ph/0606678v1 → ✅ PREFERRED
# - https://arxiv.org/pdf/astro-ph/0606678v1 → ✅ PREFERRED
# - http://arxiv.org/abs/gr-qc/9805045v1 → ✅ PREFERRED
# - https://arxiv.org/pdf/gr-qc/9805045v1 → ✅ PREFERRED
#     &lt;/pre&gt;</code></pre></div>

# %% [markdown]
# ### Different topic

# %%
topic = "recent developments in AI" 
min_ratio = 0.4
run_reflection = True

TOP_DOMAINS = {
    "wikipedia.org", "nature.com", "science.org", "arxiv.org",
    "nasa.gov", "mit.edu", "stanford.edu", "harvard.edu"
}

import json
utils.print_html(
    json.dumps(sorted(list(TOP_DOMAINS)), indent=2),
    title="<h3>Sample Preferred Domains</h3>"
)

# 1) Research
research_task = f"Find 2–3 key papers and reliable overviews about {topic}."
research_output = find_references(research_task)
utils.print_html(research_output, title=f"<h3>Research Results on {topic}</h3>")

# 2) Evaluate sources (preferred domains ratio)
flag, eval_md = evaluate_results(TOP_DOMAINS, research_output, min_ratio=min_ratio)
utils.print_html("<pre>" + eval_md + "</pre>", title="<h3>Evaluation Summary</h3>")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title"><h3>Sample Preferred Domains</h3></div><pre><code>[
#   &quot;arxiv.org&quot;,
#   &quot;harvard.edu&quot;,
#   &quot;mit.edu&quot;,
#   &quot;nasa.gov&quot;,
#   &quot;nature.com&quot;,
#   &quot;science.org&quot;,
#   &quot;stanford.edu&quot;,
#   &quot;wikipedia.org&quot;
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title"><h3>Research Results on recent developments in AI</h3></div><pre><code>Here are the findings on recent developments in AI from various sources:
#
# ### Key Academic Papers:
#
# 1. **Foundations of GenIR**:
#    - **Authors**: Qingyao Ai, Jingtao Zhan, Yiqun Liu
#    - **Publication Date**: 2025-01-06
#    - **Summary**: This paper explores the impact of generative AI models on information access systems. It highlights how generative AI can improve information generation and synthesis, creating tailored content and integrating existing information to provide grounded and precise responses. The paper discusses challenges and future directions in generative AI development.
#    - [Read the abstract](http://arxiv.org/abs/2501.02842v1) | [Read the full paper](https://arxiv.org/pdf/2501.02842v1)
#
# 2. **Meaningful Human Control: Actionable Properties for AI System Development**:
#    - **Authors**: Luciano Cavalcante Siebert et al.
#    - **Publication Date**: 2021-11-25
#    - **Summary**: This paper discusses the challenges of maintaining meaningful human control over AI systems. It identifies four actionable properties to ensure human responsibility in AI interactions, particularly in fields like automated vehicles and AI-based hiring.
#    - [Read the abstract](http://arxiv.org/abs/2112.01298v2) | [Read the full paper](https://arxiv.org/pdf/2112.01298v2)
#
# 3. **Ultra Strong Machine Learning: Teaching Humans Active Learning Strategies via Automated AI Explanations**:
#    - **Authors**: Lun Ai et al.
#    - **Publication Date**: 2025-08-31
#    - **Summary**: This work introduces LENS, a method that uses symbolic learning systems to teach humans active learning strategies. The study evaluates the effectiveness of automated explanations in improving human learning.
#    - [Read the abstract](http://arxiv.org/abs/2509.00961v1) | [Read the full paper](https://arxiv.org/pdf/2509.00961v1)
#
# ### Overview and Report:
#
# - **State of AI Report 2025**:
#   - This report provides a comprehensive analysis of the latest developments in AI. It&#x27;s a trusted annual publication offering insights into key trends and innovations in the AI field.
#   - [Read the report](https://www.stateof.ai/)
#
# ### Encyclopedic Summary:
#
# - **Superintelligence**:
#   - This Wikipedia article discusses the concept of superintelligence and its implications. Superintelligence is seen as an entity that surpasses human cognitive capabilities in virtually all areas. Researchers debate the likelihood and pathways to achieving such intelligence, whether through AI advancements or biological evolution.
#   - [Read more on Wikipedia](https://en.wikipedia.org/wiki/Superintelligence)
#
# These sources provide a mix of academic insights and general overviews of significant recent developments in AI.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title"><h3>Evaluation Summary</h3></div><pre><code>&lt;pre&gt;
#       ### Evaluation — Preferred Domains
#       - Total results: 8
#       - Preferred results: 7
#       - Ratio: 87.50%
#       - Threshold: 40%
#       - Status: ✅ PASS
#
#       **Details:**
#       - http://arxiv.org/abs/2501.02842v1 → ✅ PREFERRED
# - https://arxiv.org/pdf/2501.02842v1 → ✅ PREFERRED
# - http://arxiv.org/abs/2112.01298v2 → ✅ PREFERRED
# - https://arxiv.org/pdf/2112.01298v2 → ✅ PREFERRED
# - http://arxiv.org/abs/2509.00961v1 → ✅ PREFERRED
# - https://arxiv.org/pdf/2509.00961v1 → ✅ PREFERRED
# - https://www.stateof.ai/ → ❌ NOT PREFERRED
# - https://en.wikipedia.org/wiki/Superintelligence → ✅ PREFERRED
#     &lt;/pre&gt;</code></pre></div>
